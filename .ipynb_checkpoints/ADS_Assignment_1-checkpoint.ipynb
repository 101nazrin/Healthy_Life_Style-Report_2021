# %% [markdown]
# # 7PAM2000 Applied Data Science 1
# ## Assignment 1

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from pandas import Series

# %%
data=pd.read_excel("C:\\Users\\hp\\Downloads\\healthy_lifestyle_city_2021.xlsx")

# %%
data.shape
data1=data.head(10)

# %% [markdown]
# ### Function Defentions

# %% [markdown]
# ## Data Summary

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 12 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   City                                    44 non-null     object
#  1   Rank                                    44 non-null     int64
#  2   Sunshine_hours_City                     43 non-null     float64
#  3   Cost _of_bottle_of_water(City)          44 non-null     object
#  4   Obesity_levels(Country)                 44 non-null     float64
#  5   Life_expectancy_years_Country           44 non-null     float64
#  6   Pollution_Index_score_City              43 non-null     float64
#  7   Annualavg_hours_worked                  33 non-null     float64
#  8   Happiness_levels(Country)               44 non-null     float64
#  9   Outdoor_activities(City)                44 non-null     int64
#  10  Number_of_take_out_places(City)         44 non-null     int64
#  11  Cost_of_a_monthly_gym_membership(City)  44 non-null     object
# dtypes: float64(6), int64(3), object(3)
# memory usage: 4.2+ KB

# %%
data.boxplot()
plt.xticks(rotation=90)
plt.yticks(np.arange(0,6000,step=500))
plt.show()

# %%
data.corr(method='pearson',min_periods=1)
# Out:
#                                      Rank  Sunshine_hours_City  \
# Rank                             1.000000             0.007940
# Sunshine_hours_City              0.007940             1.000000
# Obesity_levels(Country)          0.197486             0.281304
# Life_expectancy_years_Country   -0.320034            -0.356351
# Pollution_Index_score_City       0.427297             0.393847
# Annualavg_hours_worked           0.542044             0.522778
# Happiness_levels(Country)       -0.231970            -0.334141
# Outdoor_activities(City)        -0.076972             0.129550
# Number_of_take_out_places(City)  0.363058            -0.211848
#
#                                  Obesity_levels(Country)  \
# Rank                                            0.197486
# Sunshine_hours_City                             0.281304
# Obesity_levels(Country)                         1.000000
# Life_expectancy_years_Country                   0.091071
# Pollution_Index_score_City                     -0.256251
# Annualavg_hours_worked                          0.244223
# Happiness_levels(Country)                       0.446399
# Outdoor_activities(City)                        0.150171
# Number_of_take_out_places(City)                 0.016833
#
#                                  Life_expectancy_years_Country  \
# Rank                                                 -0.320034
# Sunshine_hours_City                                  -0.356351
# Obesity_levels(Country)                               0.091071
# Life_expectancy_years_Country                         1.000000
# Pollution_Index_score_City                           -0.558713
# Annualavg_hours_worked                               -0.497729
# Happiness_levels(Country)                             0.724587
# Outdoor_activities(City)                             -0.044864
# Number_of_take_out_places(City)                       0.128163
#
#                                  Pollution_Index_score_City  \
# Rank                                               0.427297
# Sunshine_hours_City                                0.393847
# Obesity_levels(Country)                           -0.256251
# Life_expectancy_years_Country                     -0.558713
# Pollution_Index_score_City                         1.000000
# Annualavg_hours_worked                             0.569794
# Happiness_levels(Country)                         -0.765902
# Outdoor_activities(City)                           0.242622
# Number_of_take_out_places(City)                    0.187227
#
#                                  Annualavg_hours_worked  \
# Rank                                           0.542044
# Sunshine_hours_City                            0.522778
# Obesity_levels(Country)                        0.244223
# Life_expectancy_years_Country                 -0.497729
# Pollution_Index_score_City                     0.569794
# Annualavg_hours_worked                         1.000000
# Happiness_levels(Country)                     -0.545825
# Outdoor_activities(City)                       0.035117
# Number_of_take_out_places(City)               -0.024929
#
#                                  Happiness_levels(Country)  \
# Rank                                             -0.231970
# Sunshine_hours_City                              -0.334141
# Obesity_levels(Country)                           0.446399
# Life_expectancy_years_Country                     0.724587
# Pollution_Index_score_City                       -0.765902
# Annualavg_hours_worked                           -0.545825
# Happiness_levels(Country)                         1.000000
# Outdoor_activities(City)                         -0.137612
# Number_of_take_out_places(City)                   0.033116
#
#                                  Outdoor_activities(City)  \
# Rank                                            -0.076972
# Sunshine_hours_City                              0.129550
# Obesity_levels(Country)                          0.150171
# Life_expectancy_years_Country                   -0.044864
# Pollution_Index_score_City                       0.242622
# Annualavg_hours_worked                           0.035117
# Happiness_levels(Country)                       -0.137612
# Outdoor_activities(City)                         1.000000
# Number_of_take_out_places(City)                  0.528200
#
#                                  Number_of_take_out_places(City)
# Rank                                                    0.363058
# Sunshine_hours_City                                    -0.211848
# Obesity_levels(Country)                                 0.016833
# Life_expectancy_years_Country                           0.128163
# Pollution_Index_score_City                              0.187227
# Annualavg_hours_worked                                 -0.024929
# Happiness_levels(Country)                               0.033116
# Outdoor_activities(City)                                0.528200
# Number_of_take_out_places(City)                         1.000000

# %% [markdown]
# ## Data Cleaning

# %%
#Removing Colums with less than 90% of data
thresho=len(data)*.1
thresho
data.dropna(thresh=thresho,axis=1,inplace=True)
print(data.isnull().sum())
# Out:
# City                                       0
# Rank                                       0
# Sunshine_hours_City                        1
# Cost _of_bottle_of_water(City)             0
# Obesity_levels(Country)                    0
# Life_expectancy_years_Country              0
# Pollution_Index_score_City                 1
# Annualavg_hours_worked                    11
# Happiness_levels(Country)                  0
# Outdoor_activities(City)                   0
# Number_of_take_out_places(City)            0
# Cost_of_a_monthly_gym_membership(City)     0
# dtype: int64

# %%
##Filling missing values of data with the median of the series
data.Annualavg_hours_worked = data['Annualavg_hours_worked'].transform(Fill_value)
data.Sunshine_hours_City = data['Sunshine_hours_City'].transform(Fill_value)
data.Pollution_Index_score_City = data['Pollution_Index_score_City'].transform(Fill_value)

# %%
data['Pollution_Index_score_City'].median()
# Out:
# 52.64

# %%
#Removing the Character 'Â£' from the numeric columns of given data
data['Cost _of_bottle_of_water(City)']=data['Cost _of_bottle_of_water(City)'].apply(lambda x: str(x).replace('Â£','')
                                                                             if 'Â£' in str(x) else str(x))
data['Cost _of_bottle_of_water(City)']=data['Cost _of_bottle_of_water(City)'].apply(lambda x: float(x))


data['Cost_of_a_monthly_gym_membership(City)']=data['Cost_of_a_monthly_gym_membership(City)'].apply(lambda x: str(x).
                                                                             replace('Â£','')if 'Â£' in str(x) else str(x))
data['Cost_of_a_monthly_gym_membership(City)']=data['Cost_of_a_monthly_gym_membership(City)'].apply(lambda x: float(x))

# %%
#verifiying the data Cleaning
data.isnull().sum()
# Out:
# City                                      0
# Rank                                      0
# Sunshine_hours_City                       0
# Cost _of_bottle_of_water(City)            0
# Obesity_levels(Country)                   0
# Life_expectancy_years_Country             0
# Pollution_Index_score_City                0
# Annualavg_hours_worked                    0
# Happiness_levels(Country)                 0
# Outdoor_activities(City)                  0
# Number_of_take_out_places(City)           0
# Cost_of_a_monthly_gym_membership(City)    0
# dtype: int64

# %% [markdown]
# #### Creating Subdataframe

# %%
new=pd.DataFrame(data1.iloc[:,0:2])
new['Happiness Level']=data1.iloc[:,8]
new.style.set_properties(**{'color': 'blue'})
# Out:
# <style type="text/css">
# #T_4c97b_row0_col0, #T_4c97b_row0_col1, #T_4c97b_row0_col2, #T_4c97b_row1_col0, #T_4c97b_row1_col1, #T_4c97b_row1_col2, #T_4c97b_row2_col0, #T_4c97b_row2_col1, #T_4c97b_row2_col2, #T_4c97b_row3_col0, #T_4c97b_row3_col1, #T_4c97b_row3_col2, #T_4c97b_row4_col0, #T_4c97b_row4_col1, #T_4c97b_row4_col2, #T_4c97b_row5_col0, #T_4c97b_row5_col1, #T_4c97b_row5_col2, #T_4c97b_row6_col0, #T_4c97b_row6_col1, #T_4c97b_row6_col2, #T_4c97b_row7_col0, #T_4c97b_row7_col1, #T_4c97b_row7_col2, #T_4c97b_row8_col0, #T_4c97b_row8_col1, #T_4c97b_row8_col2, #T_4c97b_row9_col0, #T_4c97b_row9_col1, #T_4c97b_row9_col2 {
#   color: blue;
# }
# </style>
# <table id="T_4c97b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >City</th>
#       <th class="col_heading level0 col1" >Rank</th>
#       <th class="col_heading level0 col2" >Happiness Level</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4c97b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4c97b_row0_col0" class="data row0 col0" >Amsterdam</td>
#       <td id="T_4c97b_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_4c97b_row0_col2" class="data row0 col2" >7.440000</td>
#     </tr>
#     <tr>
#       <th id="T_4c97b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4c97b_row1_col0" class="data row1 col0" >Sydney</td>
#       <td id="T_4c97b_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_4c97b_row1_col2" class="data row1 col2" >7.220000</td>
#     </tr>
#     <tr>
#       <th id="T_4c97b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4c97b_row2_col0" class="data row2 col0" >Vienna</td>
#       <td id="T_4c97b_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_4c97b_row2_col2" class="data row2 col2" >7.290000</td>
#     </tr>
#     <tr>
#       <th id="T_4c97b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4c97b_row3_col0" class="data row3 col0" >Stockholm</td>
#       <td id="T_4c97b_row3_col1" class="data row3 col1" >4</td>
#       <td id="T_4c97b_row3_col2" class="data row3 col2" >7.350000</td>
#     </tr>
#     <tr>
#       <th id="T_4c97b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4c97b_row4_col0" class="data row4 col0" >Copenhagen</td>
#       <td id="T_4c97b_row4_col1" class="data row4 col1" >5</td>
#       <td id="T_4c97b_row4_col2" class="data row4 col2" >7.640000</td>
#     </tr>
#     <tr>
#       <th id="T_4c97b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4c97b_row5_col0" class="data row5 col0" >Helsinki</td>
#       <td id="T_4c97b_row5_col1" class="data row5 col1" >6</td>
#       <td id="T_4c97b_row5_col2" class="data row5 col2" >7.800000</td>
#     </tr>
#     <tr>
#       <th id="T_4c97b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4c97b_row6_col0" class="data row6 col0" >Fukuoka</td>
#       <td id="T_4c97b_row6_col1" class="data row6 col1" >7</td>
#       <td id="T_4c97b_row6_col2" class="data row6 col2" >5.870000</td>
#     </tr>
#     <tr>
#       <th id="T_4c97b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4c97b_row7_col0" class="data row7 col0" >Berlin</td>
#       <td id="T_4c97b_row7_col1" class="data row7 col1" >8</td>
#       <td id="T_4c97b_row7_col2" class="data row7 col2" >7.070000</td>
#     </tr>
#     <tr>
#       <th id="T_4c97b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4c97b_row8_col0" class="data row8 col0" >Barcelona</td>
#       <td id="T_4c97b_row8_col1" class="data row8 col1" >9</td>
#       <td id="T_4c97b_row8_col2" class="data row8 col2" >6.400000</td>
#     </tr>
#     <tr>
#       <th id="T_4c97b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4c97b_row9_col0" class="data row9 col0" >Vancouver</td>
#       <td id="T_4c97b_row9_col1" class="data row9 col1" >10</td>
#       <td id="T_4c97b_row9_col2" class="data row9 col2" >7.230000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Plotting and Analysis of Data

# %% [markdown]
# #### Plot 1 :Sunshine_hours_City

# %%
# Out:
#           mean        std   maximum in   minimum in
# *  2241.772727  561.422357       3542.0      1405.0

# %% [markdown]
# #### Plot 2 :Comparison between  working hours and Happiness level

# %% [markdown]
# #### Plot 3: Subplots of Outdoor Activities and Takeout Places

# %%
# Out:
#          mean        std   maximum in   minimum in
# *  213.977273  127.190297          585          23
#           mean        std   maximum in   minimum in
# *  1443.113636  1388.80327         6417         250

# %% [markdown]
# #### Plot 4: Correlation b\w  pollution index and Life Expectancy

# %%
# Out:
# -0.5511359423948121

# %% [markdown]
# #### Plot 5:Obesity Distribution in different Cities

# %% [markdown]
# #### Plot 6: Cost of bottle and monthly Gym

# %%
# Out:
#        mean      std   maximum in   minimum in
# *  1.173409  0.718642          3.2        0.15
#     mean       std   maximum in   minimum in
# *  40.42  15.006457        73.11       16.07
#     mean       std   maximum in   minimum in
# *  40.42  15.006457        73.11       16.07

# %% [markdown]
# #### Plot 7:Heatmap depicting the correlation of various metrics of data

# %%
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### END
